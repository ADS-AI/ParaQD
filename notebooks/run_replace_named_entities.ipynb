# %%
from abc import ABC, abstractmethod
import os
import re
import numpy as np
import random
import spacy
import pandas as pd
import pickle

# %%
class Operation(ABC):
    """
    Abstract class for augmenting a given text.
    """

    @abstractmethod
    def generate(self, text, **kwargs):
        """
        Corrupts the given text.
        """
        pass

# %%
class ReplaceNamedEntities(Operation):
    def __init__(self, resource_dir) -> None:
        super().__init__()
        self.nlp = spacy.load("en_core_web_sm")
        fpaths = [os.path.join(resource_dir, fpath) for fpath in os.listdir(resource_dir) if fpath.endswith(".txt")]
        self.resources = [open(fpath, "r").read().splitlines() for fpath in fpaths]

    def get_replacement(self, entity):
        possibilities = []
        for resource in self.resources:
            if entity.lower() in list(map(lambda x: x.lower(), resource)):
                possibilities.extend(random.sample(resource, 5))
                break
        possibilities = [" {} ".format(x) for x in possibilities]
        possibilities.append(" ")
        return random.choice(possibilities)

    def replace_named_entities(self, text, soften=False):
        """
        loses persons, organizations, products and places
        """
        doc = self.nlp(text)
        named_entities = set(["PERSON", "ORG", "PRODUCT", "EVENT", "GPE", "GEO"])
        ne = []
        for x in doc.ents:
            if x.label_ in named_entities:
                ne.append((x.text, x.start_char, x.end_char))
        if len(ne) == 0:
            return text
        ne_new = random.sample(ne, np.random.randint(1, min(len(ne), 3)+1))
        ne_new = sorted(ne_new, key=lambda x: x[1])
        if soften:
            ne_new = ne_new[:1]
        shift = 0
        for (entity, start, end) in ne_new:
            replacemnt = self.get_replacement(entity)
            text = text[:start-shift] + replacemnt + text[end-shift:]
            shift += end - start - len(replacemnt)
        text = re.sub("\s+", " ", text)
        return text.strip()

    def generate(self, text, **kwargs):
        soften = kwargs.get("soften", False)
        return self.replace_named_entities(text, soften)

# %%
class TF_IDF_Replacement(Operation):
    def __init__(self, resource_dir) -> None:
        super().__init__()
        tfidf_path = os.path.join(resource_dir, "tfidf_aqua.pkl")
        self.tfidf = pickle.load(open(tfidf_path, "rb"))
        self.words = self.tfidf.get_feature_names()

    def __sample(self, n=3):
        return random.sample(self.words, n)

    def generate(self, text, **kwargs):
        soften = kwargs.get("soften", False)
        
        transformed = self.tfidf.transform([text]).toarray()
        most_imp = np.argpartition(transformed, -4)[:, -4:]
        array = most_imp[0]
        question = text
        vals = []
        num_replace = np.random.randint(1, 3)
        if soften:
            num_replace = 1
        replacements = self.__sample(num_replace)
        for idx in array:
            val = transformed[0][idx]
            word = self.words[idx]
            vals.append((val, word))
        vals.sort(reverse = True)
        replaced = list(map(lambda x: x[1], vals))[:num_replace]
        for replaced_, replacement in zip(replaced, replacements):
            question = question.replace(replaced_, replacement, 1)
        return question

# %%
resource_dir = "../operators/resources"

# %%
df = pd.read_csv("../data/aqua_train_augmented.csv")
df.head()
# Out:
#                                             question  \
# 0  Two friends plan to walk along a 43-km trail, ...
# 1  In the coordinate plane, points (x, 1) and (5,...
# 2  Carl is facing very difficult financial times ...
# 3  The speed at which a man can row a boat in sti...
# 4  There are k-2 members in a certain band, inclu...
#
#                                            positive1  \
# 0  Two friends plan to walk a 43 km long trail, w...
# 1  In the coordinate plane, the points (x, 1) and...
# 2  Carl is facing very difficult financial times ...
# 3  The speed with which a man can row a boat is 2...
# 4  There are k-2 members in a particular band, in...
#
#                                            positive2  \
# 0  Two friends plan to walk along a 43-km trail, ...
# 1  In the coordinate plane, points (x, 1) and (5,...
# 2  Carl is facing very difficult financial times ...
# 3  The speed at which a man can row a boat in sti...
# 4  There are k-2 members in a certain band, inclu...
#
#                                            positive3  \
# 0  Two friends plan to walk along a forty-three-k...
# 1  In the coordinate plane, points (x, one) and (...
# 2  Carl is facing very difficult financial times ...
# 3  The speed at which a man can row a boat in sti...
# 4  There are k-two members in a certain band, inc...
#
#                                            positive4  \
# 0                                                NaN
# 1                                                NaN
# 2  Carl is facing very difficult financial times ...
# 3  The speed at which a man can row a boat in sti...
# 4                                                NaN
#
#                                                neg_0  \
# 0  Two friends plan to walk along a 43-km , start...
# 1  In the , points (x, 1) and (5, y) are on line ...
# 2  Carl is facing very difficult financial times ...
# 3  The at which a man can row a boat in still wat...
# 4  There are k-2 members in a , including Jim and...
#
#                                                neg_1  \
# 0  Two to walk along a 43-km trail, starting at o...
# 1  In the , points (x, 1) and (5, y) are on k. If...
# 2  Carl is facing very difficult financial times ...
# 3  The speed at which a can row a boat in still w...
# 4  There are in a certain band, including Jim and...
#
#                                                neg_2  \
# 0  Two friends plan to walk along a 43-km trail, ...
# 1  In the coordinate plane, points (x, 1) and (5,...
# 2  Carl is facing very difficult financial times ...
# 3  The speed at which a man can row a boat in sti...
# 4  There are k-2 members in a certain band, inclu...
#
#                                                neg_3  \
# 0  Two friends plan to walk along a 43-km trail, ...
# 1  In the coordinate plane, points (x, 1) and (5,...
# 2  is facing very difficult financial times and c...
# 3  The speed at which a man can row a boat in sti...
# 4  There are k-2 members in a certain band, inclu...
#
#                                                neg_4  \
# 0  2 friends plan to walk along a -km trail, star...
# 1  In the coordinate plane, points (x, ) and ( , ...
# 2  Carl is facing very difficult financial times ...
# 3  The speed at which a man can row a boat in sti...
# 4  There are k- members in a certain band, includ...
#
#                                                neg_5  \
# 0  Two focis plan to walk along a 43-km 9kg, star...
# 1  In the coordinate plane, points (x, 1) and (5,...
# 2  Carl is facing very difficult y20 times and ca...
# 3  Teconomists speed at which a man can row a boa...
# 4  There are k-2 members in a certain band, inclu...
#
#                                                neg_6
# 0  Two friends plan to walk along a 43-km trail, ...
# 1  In the coordinate plane, points (x, 1) and (5,...
# 2  Carl is facing very difficult financial times ...
# 3  The speed at which a man can row a boat in sti...
# 4  There are k-2 members in a certain band, inclu...

# %%
rne = ReplaceNamedEntities(resource_dir)
tfidf = TF_IDF_Replacement(resource_dir)
# Out:
# C:\Users\gupta\AppData\Local\Programs\Python\Python37\lib\site-packages\sklearn\base.py:334: UserWarning: Trying to unpickle estimator TfidfTransformer from version 0.22.2.post1 when using version 0.23.1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# C:\Users\gupta\AppData\Local\Programs\Python\Python37\lib\site-packages\sklearn\base.py:334: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 0.22.2.post1 when using version 0.23.1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)

# %%
c = 0
for idx, row in df.iterrows():
    qn = row["question"]
    text = rne.generate(qn)
    if text == qn:
        text = tfidf.generate(qn)
    row["neg_3"] = text

# %%
df.head()
# Out:
#                                             question  \
# 0  Two friends plan to walk along a 43-km trail, ...
# 1  In the coordinate plane, points (x, 1) and (5,...
# 2  Carl is facing very difficult financial times ...
# 3  The speed at which a man can row a boat in sti...
# 4  There are k-2 members in a certain band, inclu...
#
#                                            positive1  \
# 0  Two friends plan to walk a 43 km long trail, w...
# 1  In the coordinate plane, the points (x, 1) and...
# 2  Carl is facing very difficult financial times ...
# 3  The speed with which a man can row a boat is 2...
# 4  There are k-2 members in a particular band, in...
#
#                                            positive2  \
# 0  Two friends plan to walk along a 43-km trail, ...
# 1  In the coordinate plane, points (x, 1) and (5,...
# 2  Carl is facing very difficult financial times ...
# 3  The speed at which a man can row a boat in sti...
# 4  There are k-2 members in a certain band, inclu...
#
#                                            positive3  \
# 0  Two friends plan to walk along a forty-three-k...
# 1  In the coordinate plane, points (x, one) and (...
# 2  Carl is facing very difficult financial times ...
# 3  The speed at which a man can row a boat in sti...
# 4  There are k-two members in a certain band, inc...
#
#                                            positive4  \
# 0                                                NaN
# 1                                                NaN
# 2  Carl is facing very difficult financial times ...
# 3  The speed at which a man can row a boat in sti...
# 4                                                NaN
#
#                                                neg_0  \
# 0  Two friends plan to walk along a 43-km , start...
# 1  In the , points (x, 1) and (5, y) are on line ...
# 2  Carl is facing very difficult financial times ...
# 3  The at which a man can row a boat in still wat...
# 4  There are k-2 members in a , including Jim and...
#
#                                                neg_1  \
# 0  Two to walk along a 43-km trail, starting at o...
# 1  In the , points (x, 1) and (5, y) are on k. If...
# 2  Carl is facing very difficult financial times ...
# 3  The speed at which a can row a boat in still w...
# 4  There are in a certain band, including Jim and...
#
#                                                neg_2  \
# 0  Two friends plan to walk along a 43-km trail, ...
# 1  In the coordinate plane, points (x, 1) and (5,...
# 2  Carl is facing very difficult financial times ...
# 3  The speed at which a man can row a boat in sti...
# 4  There are k-2 members in a certain band, inclu...
#
#                                                neg_3  \
# 0  Two friends plan to walk along a 43-km trail, ...
# 1  In the coordinate plane, points (x, 1) and (5,...
# 2  Pavak is facing very difficult financial times...
# 3  The speed at which a man can row a boat in sti...
# 4  There are k-2 members in a certain band, inclu...
#
#                                                neg_4  \
# 0  2 friends plan to walk along a -km trail, star...
# 1  In the coordinate plane, points (x, ) and ( , ...
# 2  Carl is facing very difficult financial times ...
# 3  The speed at which a man can row a boat in sti...
# 4  There are k- members in a certain band, includ...
#
#                                                neg_5  \
# 0  Two focis plan to walk along a 43-km 9kg, star...
# 1  In the coordinate plane, points (x, 1) and (5,...
# 2  Carl is facing very difficult y20 times and ca...
# 3  Teconomists speed at which a man can row a boa...
# 4  There are k-2 members in a certain band, inclu...
#
#                                                neg_6
# 0  Two friends plan to walk along a 43-km trail, ...
# 1  In the coordinate plane, points (x, 1) and (5,...
# 2  Carl is facing very difficult financial times ...
# 3  The speed at which a man can row a boat in sti...
# 4  There are k-2 members in a certain band, inclu...

# %%
df = df.drop(columns=["neg_1"])
df.rename(columns={"neg_0": "neg_1"}, inplace=True)
df.head()
# Out:
#                                             question  \
# 0  Two friends plan to walk along a 43-km trail, ...
# 1  In the coordinate plane, points (x, 1) and (5,...
# 2  Carl is facing very difficult financial times ...
# 3  The speed at which a man can row a boat in sti...
# 4  There are k-2 members in a certain band, inclu...
#
#                                            positive1  \
# 0  Two friends plan to walk a 43 km long trail, w...
# 1  In the coordinate plane, the points (x, 1) and...
# 2  Carl is facing very difficult financial times ...
# 3  The speed with which a man can row a boat is 2...
# 4  There are k-2 members in a particular band, in...
#
#                                            positive2  \
# 0  Two friends plan to walk along a 43-km trail, ...
# 1  In the coordinate plane, points (x, 1) and (5,...
# 2  Carl is facing very difficult financial times ...
# 3  The speed at which a man can row a boat in sti...
# 4  There are k-2 members in a certain band, inclu...
#
#                                            positive3  \
# 0  Two friends plan to walk along a forty-three-k...
# 1  In the coordinate plane, points (x, one) and (...
# 2  Carl is facing very difficult financial times ...
# 3  The speed at which a man can row a boat in sti...
# 4  There are k-two members in a certain band, inc...
#
#                                            positive4  \
# 0                                                NaN
# 1                                                NaN
# 2  Carl is facing very difficult financial times ...
# 3  The speed at which a man can row a boat in sti...
# 4                                                NaN
#
#                                                neg_2  \
# 0  Two friends plan to walk along a 43-km trail, ...
# 1  In the coordinate plane, points (x, 1) and (5,...
# 2  Carl is facing very difficult financial times ...
# 3  The speed at which a man can row a boat in sti...
# 4  There are k-2 members in a certain band, inclu...
#
#                                                neg_3  \
# 0  Two friends plan to walk along a 43-km trail, ...
# 1  In the coordinate plane, points (x, 1) and (5,...
# 2  Pavak is facing very difficult financial times...
# 3  The speed at which a man can row a boat in sti...
# 4  There are k-2 members in a certain band, inclu...
#
#                                                neg_4  \
# 0  2 friends plan to walk along a -km trail, star...
# 1  In the coordinate plane, points (x, ) and ( , ...
# 2  Carl is facing very difficult financial times ...
# 3  The speed at which a man can row a boat in sti...
# 4  There are k- members in a certain band, includ...
#
#                                                neg_5  \
# 0  Two focis plan to walk along a 43-km 9kg, star...
# 1  In the coordinate plane, points (x, 1) and (5,...
# 2  Carl is facing very difficult y20 times and ca...
# 3  Teconomists speed at which a man can row a boa...
# 4  There are k-2 members in a certain band, inclu...
#
#                                                neg_6
# 0  Two friends plan to walk along a 43-km trail, ...
# 1  In the coordinate plane, points (x, 1) and (5,...
# 2  Carl is facing very difficult financial times ...
# 3  The speed at which a man can row a boat in sti...
# 4  There are k-2 members in a certain band, inclu...

# %%
df.to_csv("../data/aqua_train.csv", index=False)

# %%
df_val = pd.read_csv("../data/aqua_val_augmented.csv")

# %%
df_val.head()
# Out:
#                                             question  \
# 0  Three birds are flying at a fast rate of 900 k...
# 1  A ship is leaving a port. It takes 240 seconds...
# 2  A rectangular piece of cloth 2 feet wide was c...
# 3  In the xy-coordinate plane, which of the follo...
# 4  A travel company wants to charter a plane to t...
#
#                                            positive1  \
# 0  Three birds fly at a speed of 900 kilometres p...
# 1  A ship leaves a harbor.A 750-metre canal takes...
# 2  A rectangular piece of fabric, 2 feet wide, wa...
# 3  Which of the following points must be in the x...
# 4  A travel company wants to charter an airplane ...
#
#                                            positive2  \
# 0  Three birds are flying at a fast rate of 900 k...
# 1  A ship is leaving a port. It takes 240 seconds...
# 2  A rectangular piece of cloth 2 feet wide was c...
# 3  In the xy-coordinate plane, which of the follo...
# 4  A travel company wants to charter a plane to t...
#
#                                            positive3  \
# 0  Three birds are flying at a fast rate of 9zero...
# 1  A ship is leaving a port. It takes two hundred...
# 2  A rectangular piece of cloth two feet wide was...
# 3  In the xy-coordinate plane, which of the follo...
# 4  A travel company wants to charter a plane to t...
#
#                                            positive4  \
# 0  Three birds are flying at a fast rate of 900 k...
# 1  A ship is leaving a port. It takes 240 seconds...
# 2                                                NaN
# 3                                                NaN
# 4  A travel company wants to charter a plane to t...
#
#                                                neg_0  \
# 0  Three birds are flying at a fast rate of 900 k...
# 1  A ship is leaving a . It takes 240 seconds to ...
# 2  A rectangular piece of 2 feet wide was cut len...
# 3  In the xy- , which of the following points mus...
# 4  A travel company wants to charter a to the Bah...
#
#                                                neg_1  \
# 0  Three are flying at a of 900 kilometers per ho...
# 1  A ship is leaving a port. It takes 240 seconds...
# 2  A of cloth 2 feet wide was into two smaller s....
# 3  In the , which of the following must lie on th...
# 4  A wants to charter a plane to the Bahamas. Cha...
#
#                                                neg_2  \
# 0  Three birds are flying at a fast rate of 900 k...
# 1  A ship is leaving a port. It takes 240 seconds...
# 2  A rectangular piece of cloth 2 feet wide was c...
# 3  In the xy-coordinate plane, which of the follo...
# 4  A travel company wants to charter a plane to t...
#
#                                                neg_3  \
# 0  Three birds are flying at a fast rate of 900 k...
# 1  A ship is leaving a subscription. It takes 240...
# 2  A rectangular accelerated of cloth 2 mismatche...
# 3  In the xy-coordinate plane, which of the follo...
# 4  A travel company wants to charter a plane to t...
#
#                                                neg_4  \
# 0  birds are flying at a fast rate of kilometers ...
# 1  A ship is leaving a port. It takes seconds to ...
# 2  A rectangular piece of cloth feet wide was cut...
# 3  In the xy-coordinate plane, which of the follo...
# 4  A travel company wants to charter a plane to t...
#
#                                                neg_5  \
# 0  Three birds are flying at a fast rate of 900 k...
# 1  A ship is leaving a unique. It takes 240 secon...
# 2  A rectangular pity of cloth 2 wbc wide was cut...
# 3  The points must lie on the line kx + 2y for ev...
# 4  A travel complete wants to charter a liz to th...
#
#                                                neg_6
# 0  Three birds are flying at a fast rate of 900 m...
# 1  A ship is leaving a port. It takes 240 seconds...
# 2  A rectangular piece of cloth 2 kilometres wide...
# 3  In the xy-coordinate plane, which of the follo...
# 4  A travel company wants to charter a plane to t...

# %%
c = 0
for idx, row in df_val.iterrows():
    qn = row["question"]
    text = rne.generate(qn)
    if text == qn:
        text = tfidf.generate(qn)
    row["neg_3"] = text

# %%
df_val = df_val.drop(columns=["neg_1"])
df_val.rename(columns={"neg_0": "neg_1"}, inplace=True)
df_val.head()
# Out:
#                                             question  \
# 0  Three birds are flying at a fast rate of 900 k...
# 1  A ship is leaving a port. It takes 240 seconds...
# 2  A rectangular piece of cloth 2 feet wide was c...
# 3  In the xy-coordinate plane, which of the follo...
# 4  A travel company wants to charter a plane to t...
#
#                                            positive1  \
# 0  Three birds fly at a speed of 900 kilometres p...
# 1  A ship leaves a harbor.A 750-metre canal takes...
# 2  A rectangular piece of fabric, 2 feet wide, wa...
# 3  Which of the following points must be in the x...
# 4  A travel company wants to charter an airplane ...
#
#                                            positive2  \
# 0  Three birds are flying at a fast rate of 900 k...
# 1  A ship is leaving a port. It takes 240 seconds...
# 2  A rectangular piece of cloth 2 feet wide was c...
# 3  In the xy-coordinate plane, which of the follo...
# 4  A travel company wants to charter a plane to t...
#
#                                            positive3  \
# 0  Three birds are flying at a fast rate of 9zero...
# 1  A ship is leaving a port. It takes two hundred...
# 2  A rectangular piece of cloth two feet wide was...
# 3  In the xy-coordinate plane, which of the follo...
# 4  A travel company wants to charter a plane to t...
#
#                                            positive4  \
# 0  Three birds are flying at a fast rate of 900 k...
# 1  A ship is leaving a port. It takes 240 seconds...
# 2                                                NaN
# 3                                                NaN
# 4  A travel company wants to charter a plane to t...
#
#                                                neg_1  \
# 0  Three birds are flying at a fast rate of 900 k...
# 1  A ship is leaving a . It takes 240 seconds to ...
# 2  A rectangular piece of 2 feet wide was cut len...
# 3  In the xy- , which of the following points mus...
# 4  A travel company wants to charter a to the Bah...
#
#                                                neg_2  \
# 0  Three birds are flying at a fast rate of 900 k...
# 1  A ship is leaving a port. It takes 240 seconds...
# 2  A rectangular piece of cloth 2 feet wide was c...
# 3  In the xy-coordinate plane, which of the follo...
# 4  A travel company wants to charter a plane to t...
#
#                                                neg_3  \
# 0  Three birds are flying at a fast rate of 900 k...
# 1  A ship is leaving a arethe. It takes 240 secon...
# 2  A rectangular piece of cloth 2 kh wide was cut...
# 3  In the xy-coordinate plane, which of the follo...
# 4  A travel company wants to charter a plane to t...
#
#                                                neg_4  \
# 0  birds are flying at a fast rate of kilometers ...
# 1  A ship is leaving a port. It takes seconds to ...
# 2  A rectangular piece of cloth feet wide was cut...
# 3  In the xy-coordinate plane, which of the follo...
# 4  A travel company wants to charter a plane to t...
#
#                                                neg_5  \
# 0  Three birds are flying at a fast rate of 900 k...
# 1  A ship is leaving a unique. It takes 240 secon...
# 2  A rectangular pity of cloth 2 wbc wide was cut...
# 3  The points must lie on the line kx + 2y for ev...
# 4  A travel complete wants to charter a liz to th...
#
#                                                neg_6
# 0  Three birds are flying at a fast rate of 900 m...
# 1  A ship is leaving a port. It takes 240 seconds...
# 2  A rectangular piece of cloth 2 kilometres wide...
# 3  In the xy-coordinate plane, which of the follo...
# 4  A travel company wants to charter a plane to t...

# %%
df_val.to_csv("../data/aqua_val.csv", index=False)
