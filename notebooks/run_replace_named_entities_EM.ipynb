# %%
from abc import ABC, abstractmethod
import os
import re
import numpy as np
import random
import spacy
import pandas as pd
import pickle
import json

# %%
class Operation(ABC):
    """
    Abstract class for augmenting a given text.
    """

    @abstractmethod
    def generate(self, text, **kwargs):
        """
        Corrupts the given text.
        """
        pass

# %%
class ReplaceNamedEntities(Operation):
    def __init__(self, resource_dir) -> None:
        super().__init__()
        self.nlp = spacy.load("en_core_web_sm")
        fpaths = [os.path.join(resource_dir, fpath) for fpath in os.listdir(resource_dir) if fpath.endswith(".txt")]
        self.resources = [open(fpath, "r").read().splitlines() for fpath in fpaths]

    def get_replacement(self, entity):
        possibilities = []
        for resource in self.resources:
            if entity.lower() in list(map(lambda x: x.lower(), resource)):
                possibilities.extend(random.sample(resource, 5))
                break
        possibilities = [" {} ".format(x) for x in possibilities]
        possibilities.append(" ")
        return random.choice(possibilities)

    def replace_named_entities(self, text, soften=False):
        """
        loses persons, organizations, products and places
        """
        doc = self.nlp(text)
        named_entities = set(["PERSON", "ORG", "PRODUCT", "EVENT", "GPE", "GEO"])
        ne = []
        for x in doc.ents:
            if x.label_ in named_entities:
                ne.append((x.text, x.start_char, x.end_char))
        if len(ne) == 0:
            return text
        ne_new = random.sample(ne, np.random.randint(1, min(len(ne), 3)+1))
        ne_new = sorted(ne_new, key=lambda x: x[1])
        if soften:
            ne_new = ne_new[:1]
        shift = 0
        for (entity, start, end) in ne_new:
            replacemnt = self.get_replacement(entity)
            text = text[:start-shift] + replacemnt + text[end-shift:]
            shift += end - start - len(replacemnt)
        text = re.sub("\s+", " ", text)
        return text.strip()

    def generate(self, text, **kwargs):
        soften = kwargs.get("soften", False)
        return self.replace_named_entities(text, soften)

# %%
class TF_IDF_Replacement(Operation):
    def __init__(self, resource_dir) -> None:
        super().__init__()
        tfidf_path = os.path.join(resource_dir, "tfidf_em.pkl")
        self.tfidf = pickle.load(open(tfidf_path, "rb"))
        self.words = self.tfidf.get_feature_names()

    def __sample(self, n=3):
        return random.sample(self.words, n)

    def generate(self, text, **kwargs):
        soften = kwargs.get("soften", False)
        
        transformed = self.tfidf.transform([text]).toarray()
        most_imp = np.argpartition(transformed, -4)[:, -4:]
        array = most_imp[0]
        question = text
        vals = []
        num_replace = np.random.randint(1, 3)
        if soften:
            num_replace = 1
        replacements = self.__sample(num_replace)
        for idx in array:
            val = transformed[0][idx]
            word = self.words[idx]
            vals.append((val, word))
        vals.sort(reverse = True)
        replaced = list(map(lambda x: x[1], vals))[:num_replace]
        for replaced_, replacement in zip(replaced, replacements):
            question = question.replace(replaced_, replacement, 1)
        return question

# %%
resource_dir = "../operators/resources"

# %%
df = pd.read_csv("../data/EM/train_em_ours.csv")
print(df.shape)
df.head()
# Out:
# (10085, 12)
#                                             question  \
# 0  A circle has an area of 36 square unit. The le...
# 1    In the figure given below, find the value of z.
# 2          The number whch is not irrational will be
# 3  How many rational numbers we can find between ...
# 4  The number of circle passing through a given p...
#
#                                            positive1  \
# 0  One circle has an area of 36 square units.The ...
# 1              Below you will find the value of e.g.
# 2            The number, which is not irrational, is
# 3  How many rational numbers can we find among tw...
# 4   The number of circles passing a certain point is
#
#                                            positive2  \
# 0  A circle has an area of 36 square unit. The le...
# 1    In the figure given below, find the value of z.
# 2          The number whch is not irrational will be
# 3  How many rational numbers we can find between ...
# 4  The number of circle passing through a given p...
#
#                                            positive3 positive4  \
# 0  A circle has an area of thirty-six square unit...       NaN
# 1    In the figure given below, find the value of z.       NaN
# 2          The number whch is not irrational will be       NaN
# 3  How many rational numbers we can find between ...       NaN
# 4  The number of circle passing through a given p...       NaN
#
#                                                neg_0  \
# 0  A has an area of 36 square unit. The length of...
# 1          In the figure given below, find the of z.
# 2                      The is not irrational will be
# 3      How we can find between two rational numbers?
# 4     The number of passing through a given point is
#
#                                                neg_1  \
# 0  A has an area of 36 square unit. The of the it...
# 1           In the given below, find the value of z.
# 2                                 The is not will be
# 3                      How many we can between two ?
# 4                    The of through a given point is
#
#                                            neg_2  \
# 0        A circle has an area of 36 square unit.
# 1            In the figure given below, find the
# 2                         The number whch is not
# 3  How many rational numbers we can find between
# 4         The number of circle passing through a
#
#                                                neg_3  \
# 0  A circle has an area of basketball square away...
# 1    In the figure given moves, find the value of z.
# 2          The number wolud is not parrallel will be
# 3  How many compact square we can find between tw...
# 4      The number of circle acd 68x a given point is
#
#                                                neg_4  \
# 0  A circle has an area of square unit. The lengt...
# 1   In the figure given convex, find the value of z.
# 2      The number improper is not irrational will be
# 3  How many rational numbers we can find between ...
# 4   The number of circle public bag a given point is
#
#                                                neg_5  \
# 0             36 square unit is the area of a circle
# 1       The value of Z is given in the figure below.
# 2                   No, the number is not irrational
# 3  Can we find between two and three rational num...
# 4  There is a number of circles passing through a...
#
#                                                neg_6
# 0  A circle has an area of entry square pictograp...
# 1    In the figure given sugar, find the value of z.
# 2      The number combined is not irrational will be
# 3  How many 115 numbers we can find between two r...
# 4  The number of circle 941 through a given point is

# %%
rne = ReplaceNamedEntities(resource_dir)
tfidf = TF_IDF_Replacement(resource_dir)
# Out:
# C:\Users\gupta\AppData\Local\Programs\Python\Python37\lib\site-packages\sklearn\base.py:334: UserWarning: Trying to unpickle estimator TfidfTransformer from version 0.22.2.post1 when using version 0.23.1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# C:\Users\gupta\AppData\Local\Programs\Python\Python37\lib\site-packages\sklearn\base.py:334: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 0.22.2.post1 when using version 0.23.1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)

# %%
c = 0
for idx, row in df.iterrows():
    qn = row["question"]
    text = rne.generate(qn)
    if text == qn:
        text = tfidf.generate(qn)
    row["neg_3"] = text

# %%
df.head()
# Out:
#                                             question  \
# 0  A circle has an area of 36 square unit. The le...
# 1    In the figure given below, find the value of z.
# 2          The number whch is not irrational will be
# 3  How many rational numbers we can find between ...
# 4  The number of circle passing through a given p...
#
#                                            positive1  \
# 0  One circle has an area of 36 square units.The ...
# 1              Below you will find the value of e.g.
# 2            The number, which is not irrational, is
# 3  How many rational numbers can we find among tw...
# 4   The number of circles passing a certain point is
#
#                                            positive2  \
# 0  A circle has an area of 36 square unit. The le...
# 1    In the figure given below, find the value of z.
# 2          The number whch is not irrational will be
# 3  How many rational numbers we can find between ...
# 4  The number of circle passing through a given p...
#
#                                            positive3 positive4  \
# 0  A circle has an area of thirty-six square unit...       NaN
# 1    In the figure given below, find the value of z.       NaN
# 2          The number whch is not irrational will be       NaN
# 3  How many rational numbers we can find between ...       NaN
# 4  The number of circle passing through a given p...       NaN
#
#                                                neg_0  \
# 0  A has an area of 36 square unit. The length of...
# 1          In the figure given below, find the of z.
# 2                      The is not irrational will be
# 3      How we can find between two rational numbers?
# 4     The number of passing through a given point is
#
#                                                neg_1  \
# 0  A has an area of 36 square unit. The of the it...
# 1           In the given below, find the value of z.
# 2                                 The is not will be
# 3                      How many we can between two ?
# 4                    The of through a given point is
#
#                                            neg_2  \
# 0        A circle has an area of 36 square unit.
# 1            In the figure given below, find the
# 2                         The number whch is not
# 3  How many rational numbers we can find between
# 4         The number of circle passing through a
#
#                                                neg_3  \
# 0  A circle has an area of 36 square km. The leng...
# 1       In the figure given below, find the value of
# 2         The number wrist is not irrational will be
# 3  How many collecting filled we can find between...
# 4   The number of circle 91a92 6174 a given point is
#
#                                                neg_4  \
# 0  A circle has an area of square unit. The lengt...
# 1   In the figure given convex, find the value of z.
# 2      The number improper is not irrational will be
# 3  How many rational numbers we can find between ...
# 4   The number of circle public bag a given point is
#
#                                                neg_5  \
# 0             36 square unit is the area of a circle
# 1       The value of Z is given in the figure below.
# 2                   No, the number is not irrational
# 3  Can we find between two and three rational num...
# 4  There is a number of circles passing through a...
#
#                                                neg_6
# 0  A circle has an area of entry square pictograp...
# 1    In the figure given sugar, find the value of z.
# 2      The number combined is not irrational will be
# 3  How many 115 numbers we can find between two r...
# 4  The number of circle 941 through a given point is

# %%
df = df.drop(columns=["neg_1"])
df.rename(columns={"neg_0": "neg_1"}, inplace=True)
df.head()
# Out:
#                                             question  \
# 0  A circle has an area of 36 square unit. The le...
# 1    In the figure given below, find the value of z.
# 2          The number whch is not irrational will be
# 3  How many rational numbers we can find between ...
# 4  The number of circle passing through a given p...
#
#                                            positive1  \
# 0  One circle has an area of 36 square units.The ...
# 1              Below you will find the value of e.g.
# 2            The number, which is not irrational, is
# 3  How many rational numbers can we find among tw...
# 4   The number of circles passing a certain point is
#
#                                            positive2  \
# 0  A circle has an area of 36 square unit. The le...
# 1    In the figure given below, find the value of z.
# 2          The number whch is not irrational will be
# 3  How many rational numbers we can find between ...
# 4  The number of circle passing through a given p...
#
#                                            positive3 positive4  \
# 0  A circle has an area of thirty-six square unit...       NaN
# 1    In the figure given below, find the value of z.       NaN
# 2          The number whch is not irrational will be       NaN
# 3  How many rational numbers we can find between ...       NaN
# 4  The number of circle passing through a given p...       NaN
#
#                                                neg_1  \
# 0  A has an area of 36 square unit. The length of...
# 1          In the figure given below, find the of z.
# 2                      The is not irrational will be
# 3      How we can find between two rational numbers?
# 4     The number of passing through a given point is
#
#                                            neg_2  \
# 0        A circle has an area of 36 square unit.
# 1            In the figure given below, find the
# 2                         The number whch is not
# 3  How many rational numbers we can find between
# 4         The number of circle passing through a
#
#                                                neg_3  \
# 0  A circle has an area of 36 square km. The leng...
# 1       In the figure given below, find the value of
# 2         The number wrist is not irrational will be
# 3  How many collecting filled we can find between...
# 4   The number of circle 91a92 6174 a given point is
#
#                                                neg_4  \
# 0  A circle has an area of square unit. The lengt...
# 1   In the figure given convex, find the value of z.
# 2      The number improper is not irrational will be
# 3  How many rational numbers we can find between ...
# 4   The number of circle public bag a given point is
#
#                                                neg_5  \
# 0             36 square unit is the area of a circle
# 1       The value of Z is given in the figure below.
# 2                   No, the number is not irrational
# 3  Can we find between two and three rational num...
# 4  There is a number of circles passing through a...
#
#                                                neg_6
# 0  A circle has an area of entry square pictograp...
# 1    In the figure given sugar, find the value of z.
# 2      The number combined is not irrational will be
# 3  How many 115 numbers we can find between two r...
# 4  The number of circle 941 through a given point is

# %%
df.to_csv("../data/EM/em_train.csv", index=False)

# %%
df_val = pd.read_csv("../data/EM/val_samples_em.csv")

# %%
df_val.head()
# Out:
#                                             question  \
# 0  A cubical block of side 14 cm is surmounted by...
# 1  Numerical coefficients of the expression 4x – ...
# 2  Rational numbers between any two rational numb...
# 3         In the given figure, the value of a equals
# 4      The largest side of a right angle triangle is
#
#                                            positive1  \
# 0  A cubic block with a side length of 14 cm is t...
# 1   Numerical coefficients of expression 4x - 3y are
# 2  Rational numbers are / are between any two rat...
# 3  In the given illustration, the value of a corr...
# 4      The largest side of a rectangular triangle is
#
#                                            positive2  \
# 0  A cubical block of side 14 cm is surmounted by...
# 1  Numerical coefficients of the expression 4x – ...
# 2  Rational numbers between any two rational numb...
# 3         In the given figure, the value of a equals
# 4      The largest side of a right angle triangle is
#
#                                            positive3  \
# 0  A cubical block of side fourteen cm is surmoun...
# 1  Numerical coefficients of the expression fourx...
# 2  Rational numbers between any two rational numb...
# 3         In the given figure, the value of a equals
# 4      The largest side of a right angle triangle is
#
#                                            positive4  \
# 0  A cubical block of side 14 centimetre is surmo...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                neg_0  \
# 0  A of side 14 cm is surmounted by a hemisphere....
# 1          Numerical coefficients of the 4x – 3y are
# 2            Rational numbers between any two is/are
# 3               In the given , the value of a equals
# 4                           The largest side of a is
#
#                                                neg_1  \
# 0  A of side 14 cm is by a hemisphere. The total ...
# 1             Numerical coefficients of the – 3y are
# 2            Rational numbers between any two is/are
# 3                      In the given , the value of a
# 4                                  The of a right is
#
#                                                neg_2  \
# 0  A cubical block of side 14 cm is surmounted by...
# 1        Numerical coefficients of the expression 4x
# 2                   Rational numbers between any two
# 3                     In the given figure, the value
# 4                        The largest side of a right
#
#                                                neg_3  \
# 0  A cubical block of side 14 cm is aob by a hemi...
# 1     Numerical stamps of the expression 4x – 3y are
# 2  Rational numbers between any two nmeasures num...
# 3           In the given figure, the value of a took
# 4          The get side of a right angle triangle is
#
#                                                neg_4  \
# 0  A cubical block of side cm is surmounted by a ...
# 1  Numerical coefficients of the expression x – y...
# 2  Rational numbers between any rational numbers ...
# 3          In the given figure, the value of a bowls
# 4          The bce side of a right angle triangle is
#
#                                                neg_5  \
# 0  A cubical block of side 14 cm is ndash by a he...
# 1      The coefficients of the expression are 4x 3Y.
# 2      Any two rational numbers are rational numbers
# 3       The value of a equals is given in the figure
# 4       A right angle triangle has the largest side.
#
#                                                neg_6
# 0  A cubical block of side 14 mm is surmounted by...
# 1    Numerical fridays of the expression 4x – 3y are
# 2  Rational 170 between any two marble numbers is...
# 3             In the given figure, the value of a yz
# 4      The braces side of a opting angle triangle is

# %%
c = 0
for idx, row in df_val.iterrows():
    qn = row["question"]
    text = rne.generate(qn)
    if text == qn:
        text = tfidf.generate(qn)
    row["neg_3"] = text

# %%
df_val = df_val.drop(columns=["neg_1"])
df_val.rename(columns={"neg_0": "neg_1"}, inplace=True)
df_val.head()
# Out:
#                                             question  \
# 0  A cubical block of side 14 cm is surmounted by...
# 1  Numerical coefficients of the expression 4x – ...
# 2  Rational numbers between any two rational numb...
# 3         In the given figure, the value of a equals
# 4      The largest side of a right angle triangle is
#
#                                            positive1  \
# 0  A cubic block with a side length of 14 cm is t...
# 1   Numerical coefficients of expression 4x - 3y are
# 2  Rational numbers are / are between any two rat...
# 3  In the given illustration, the value of a corr...
# 4      The largest side of a rectangular triangle is
#
#                                            positive2  \
# 0  A cubical block of side 14 cm is surmounted by...
# 1  Numerical coefficients of the expression 4x – ...
# 2  Rational numbers between any two rational numb...
# 3         In the given figure, the value of a equals
# 4      The largest side of a right angle triangle is
#
#                                            positive3  \
# 0  A cubical block of side fourteen cm is surmoun...
# 1  Numerical coefficients of the expression fourx...
# 2  Rational numbers between any two rational numb...
# 3         In the given figure, the value of a equals
# 4      The largest side of a right angle triangle is
#
#                                            positive4  \
# 0  A cubical block of side 14 centimetre is surmo...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                neg_1  \
# 0  A of side 14 cm is surmounted by a hemisphere....
# 1          Numerical coefficients of the 4x – 3y are
# 2            Rational numbers between any two is/are
# 3               In the given , the value of a equals
# 4                           The largest side of a is
#
#                                                neg_2  \
# 0  A cubical block of side 14 cm is surmounted by...
# 1        Numerical coefficients of the expression 4x
# 2                   Rational numbers between any two
# 3                     In the given figure, the value
# 4                        The largest side of a right
#
#                                                neg_3  \
# 0  A 3yx block of side 14 cm is taj by a hemisphe...
# 1      Numerical below of the expression 4x – 3y are
# 2  Rational numbers between any two it numbers is...
# 3           In the given figure, the value of a aman
# 4      The thelength side of a him angle triangle is
#
#                                                neg_4  \
# 0  A cubical block of side cm is surmounted by a ...
# 1  Numerical coefficients of the expression x – y...
# 2  Rational numbers between any rational numbers ...
# 3          In the given figure, the value of a bowls
# 4          The bce side of a right angle triangle is
#
#                                                neg_5  \
# 0  A cubical block of side 14 cm is ndash by a he...
# 1      The coefficients of the expression are 4x 3Y.
# 2      Any two rational numbers are rational numbers
# 3       The value of a equals is given in the figure
# 4       A right angle triangle has the largest side.
#
#                                                neg_6
# 0  A cubical block of side 14 mm is surmounted by...
# 1    Numerical fridays of the expression 4x – 3y are
# 2  Rational 170 between any two marble numbers is...
# 3             In the given figure, the value of a yz
# 4      The braces side of a opting angle triangle is

# %%
df_val.to_csv("../data/EM/em_val.csv", index=False)
